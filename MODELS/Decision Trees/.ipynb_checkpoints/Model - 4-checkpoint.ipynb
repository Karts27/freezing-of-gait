# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.preprocessing import normalize
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.utils import shuffle

os.chdir(r"F:\\KARTIK\\2021\\Freezing of Gait")

# %%
data_path = os.path.join(os.getcwd(), 'dataset_fog_release', 'dataset', 'FINAL FEATURES', 'final_ftrs_size_1.5_4.csv')
if os.path.exists(data_path):
    print(True)
# Out:
# True

# %%
df = pd.read_csv(data_path)
df.head()
# Out:
#    Unnamed: 0  0  Minimum_A_F  Maximum_A_F     RMS_A_F   Variance_A_F  \
# 0         148  0        -1919          939  701.148433  382316.897500
# 1        8379  0           90          131  117.140607      87.710693
# 2        3457  0         -969         3090  500.699885  241538.295900
# 3         475  0         -333         -292  312.147326      82.202881
# 4        5097  0        -1191         2494  706.543468  492139.794700
#
#       STD_A_F  Kurtosis_A_F  Skewness_A_F  RangeA_F  ...     STD_A_V  \
# 0  618.317796      0.851470     -0.817700      2858  ...  495.329810
# 1    9.365399     -0.108976     -0.601516        41  ...    8.941597
# 2  491.465458     21.274052      3.754156      4059  ...  291.929356
# 3    9.066580      0.420634     -0.247686        41  ...    9.668113
# 4  701.526760      3.953054      1.766946      3685  ...   93.730247
#
#    Kurtosis_A_V  RangeA_V  Minimum_A_L     RMS_A_L   Variance_A_L  RangeA_L  \
# 0      8.188622      3432        -2079  549.072257  180832.663100      3643
# 1     -0.384228        39          158  189.480004     128.495850        59
# 2      5.553289      2118         -158  317.402199   28869.897460      1257
# 3     -0.339464        39          524  553.324103     116.577148        60
# 4      1.628769       471         -534  334.530735   68164.475590      1316
#
#      EN_A_F    EN_A_V    EN_A_L
# 0  31462984  74054915  19294742
# 1    878203  66423542   2297771
# 2  16044824  69963264   6447626
# 3   6235901  44426541  19594724
# 4  31949035  70049075   7162292
#
# [5 rows x 24 columns]

# %%
df['Energy_Mean'] = (df['EN_A_F'] + df['EN_A_V'] + df['EN_A_L'])/3
df = df.drop(['EN_A_F','EN_A_V','EN_A_L','Unnamed: 0'], axis = 1)

# %%
df.head()
# Out:
#    0  Minimum_A_F  Maximum_A_F     RMS_A_F   Variance_A_F     STD_A_F  \
# 0  0        -1919          939  701.148433  382316.897500  618.317796
# 1  0           90          131  117.140607      87.710693    9.365399
# 2  0         -969         3090  500.699885  241538.295900  491.465458
# 3  0         -333         -292  312.147326      82.202881    9.066580
# 4  0        -1191         2494  706.543468  492139.794700  701.526760
#
#    Kurtosis_A_F  Skewness_A_F  RangeA_F  Minimum_A_V  ...      RMS_A_V  \
# 0      0.851470     -0.817700      2858            9  ...  1075.689568
# 1     -0.108976     -0.601516        41         1000  ...  1018.757991
# 2     21.274052      3.754156      4059           68  ...  1045.550573
# 3      0.420634     -0.247686        41          813  ...   833.165472
# 4      3.953054      1.766946      3685          872  ...  1046.191568
#
#     Variance_A_V     STD_A_V  Kurtosis_A_V  RangeA_V  Minimum_A_L     RMS_A_L  \
# 0  245351.620800  495.329810      8.188622      3432        -2079  549.072257
# 1      79.952148    8.941597     -0.384228        39          158  189.480004
# 2   85222.749020  291.929356      5.553289      2118         -158  317.402199
# 3      93.472412    9.668113     -0.339464        39          524  553.324103
# 4    8785.359131   93.730247      1.628769       471         -534  334.530735
#
#     Variance_A_L  RangeA_L   Energy_Mean
# 0  180832.663100      3643  4.160421e+07
# 1     128.495850        59  2.319984e+07
# 2   28869.897460      1257  3.081857e+07
# 3     116.577148        60  2.341906e+07
# 4   68164.475590      1316  3.638680e+07
#
# [5 rows x 21 columns]

# %%
# Split the data for the classifier
y = df['0'].values
X = df.iloc[:,1:]
X = normalize(X)
X, y = shuffle(X, y, random_state = 2)

# %%
# Initiate the 10 - fold split 
kf = StratifiedKFold(n_splits = 10, shuffle = True, random_state = 2)

# Initiate a decision tree model
clf = DecisionTreeClassifier(class_weight=None, 
                            criterion='entropy',
                            max_depth=10,
                            max_features=3, 
                            max_leaf_nodes=None,
                            min_impurity_decrease=0.0, 
                            min_samples_leaf=18, 
                            min_samples_split=10,
                            min_weight_fraction_leaf=0.0, 
                            #presort=False,
                            random_state=2, 
                            splitter='best'
                            )
# split()  method generate indices to split data into training and test set.
for (train_index, test_index), i in zip(kf.split(X, y), range(10)):
    print(f'Fold:{i}, Train set: {len(train_index)}, Test set:{len(test_index)}')
# Out:
# Fold:0, Train set: 1988, Test set:221
# Fold:1, Train set: 1988, Test set:221
# Fold:2, Train set: 1988, Test set:221
# Fold:3, Train set: 1988, Test set:221
# Fold:4, Train set: 1988, Test set:221
# Fold:5, Train set: 1988, Test set:221
# Fold:6, Train set: 1988, Test set:221
# Fold:7, Train set: 1988, Test set:221
# Fold:8, Train set: 1988, Test set:221
# Fold:9, Train set: 1989, Test set:220

# %%
score = cross_val_score(clf, X, y, cv= kf, scoring="accuracy")
print(f'Scores for each fold are: {score}')
print(f'Average score: {"{:.2f}".format(score.mean())}')
# Out:
# Scores for each fold are: [0.75113122 0.72850679 0.75565611 0.73755656 0.77828054 0.76923077
#  0.76470588 0.77375566 0.79638009 0.76363636]
# Average score: 0.76

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 2, stratify = y, test_size = 0.40)

# %%
m = clf.fit(X_train, y_train)
y_pred = m.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7567873303167421

# %%
cnf = confusion_matrix(y_test, y_pred)
print(cnf)
# Out:
# [[ 52  87   3]
#  [ 32 610   5]
#  [  4  84   7]]

# %%
# For class pre-FoG
tp = cnf[1][1]
tn = cnf[0][0] + cnf[0][2] + cnf[2][0] + cnf[2][2]
fp = cnf[1][0] + cnf[1][2]
fn = cnf[0][1] + cnf[2][1]

# %%
precision = tp/(tp + fp)
recall =  tp / (tp + fn)    #sensitivity
F1_score = (2*tp) / (2*tp + fp + fn)

# %%
print("The evaluation metrics are:\nprecision = {},\nrecall = {}, \nF1-score = {}".format(precision, recall, F1_score) )
# Out:
# The evaluation metrics are:
# precision = 0.9428129829984544,
# recall = 0.7810499359795134,
# F1-score = 0.8543417366946778
