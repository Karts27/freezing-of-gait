# %% [raw]
# time_1.csv
#
# 0            ----      Action
#
# 1            ----      Minimum_A_F
# 2            ----      Maximum_A_F
# 3            ----      Median_A_F
# 4            ----      Mean_A_F
# 5             ----      ArmMean_A_F
# 6            ----      RMS_A_F
# 7            ----      Variance_A_F
# 8            ----      STD_A_F
# 9            ----      Kurtosis_A_F
# 10            ----      Skewness_A_F
# 11            ----      TrimMean_A_F
# 12            ----      AsymmetryCoefficient_A_F
# 13            ----      ZCR_A_F
# 14            ----      MCR_A_F
# 15            ----      Range_A_F
#
# 16            ----      Minimum_A_V
# 17            ----      Maximum_A_V
# 18            ----      Median_A_V
# 19            ----      Mean_A_V
# 20            ----      ArmMean_A_V
# 21            ----      RMS_A_V
# 22            ----      Variance_A_V
# 23            ----      STD_A_V
# 24            ----      Kurtosis_A_V
# 25            ----      Skewness_A_V
# 26            ----      TrimMean_A_V
# 27            ----      AsymmetryCoefficient_A_V
# 28            ----      ZCR_A_V
# 29            ----      MCR_A_V
# 30            ----      Range_A_V
#
# 31            ----      Minimum_A_L
# 32            ----      Maximum_A_L
# 33            ----      Median_A_L
# 34            ----      Mean_A_L
# 35            ----      ArmMean_A_L
# 36            ----      RMS_A_L
# 37            ----      Variance_A_L
# 38            ----      STD_A_L
# 39            ----      Kurtosis_A_L
# 40            ----      Skewness_A_L
# 41            ----      TrimMean_A_L
# 42            ----      AsymmetryCoefficient_A_L
# 43            ----      ZCR_A_L
# 44            ----      MCR_A_L
# 45            ----      Range_A_L
#
# 46            ----      Minimum_L_F
# 47            ----      Maximum_L_F
# 48            ----      Median_L_F
# 49            ----      Mean_L_F
# 50            ----      ArmMean_L_F
# 51            ----      RMS_L_F
# 52            ----      Variance_L_F
# 53            ----      STD_L_F
# 54            ----      Kurtosis_L_F
# 55            ----      Skewness_L_F
# 56            ----      TrimMean_L_F
# 57            ----      AsymmetryCoefficient_L_F
# 58            ----      ZCR_L_F
# 59            ----      MCR_L_F
# 60            ----      Range_L_F
#
# 61            ----      Minimum_L_V
# 62            ----      Maximum_L_V
# 63            ----      Median_L_V
# 64            ----      Mean_L_V
# 65            ----      ArmMean_L_V
# 66            ----      RMS_L_V
# 67            ----      Variance_L_V
# 68            ----      STD_L_V
# 69            ----      Kurtosis_L_V
# 70            ----      Skewness_L_V
# 71           ----      TrimMean_L_V
# 72            ----      AsymmetryCoefficient_L_V
# 73            ----      ZCR_L_V
# 74            ----      MCR_L_V
# 75            ----      Range_L_V
#
# 76            ----      Minimum_L_L
# 77            ----      Maximum_L_L
# 78            ----      Median_L_L
# 79            ----      Mean_L_L
# 80            ----      ArmMean_L_L
# 81            ----      RMS_L_L
# 82            ----      Variance_L_L
# 83            ----      STD_L_L
# 84            ----      Kurtosis_L_L
# 85            ----      Skewness_L_L
# 86            ----      TrimMean_L_L
# 87            ----      AsymmetryCoefficient_L_L
# 88            ----      ZCR_L_L
# 89            ----      MCR_L_L
# 90            ----      Range_L_L
#
# 91            ----      Minimum_T_F
# 92            ----      Maximum_T_F
# 93            ----      Median_T_F
# 94            ----      Mean_T_F
# 95            ----      ArmMean_T_F
# 96            ----      RMS_T_F
# 97            ----      Variance_T_F
# 98            ----      STD_T_F
# 99            ----      Kurtosis_T_F
# 100            ----      Skewness_T_F
# 101           ----      TrimMean_T_F
# 102            ----      AsymmetryCoefficient_T_F
# 103            ----      ZCR_T_F
# 104            ----      MCR_T_F
# 105            ----      Range_T_F
#
# 106            ----      Minimum_T_V
# 107            ----      Maximum_T_V
# 108            ----      Median_T_V
# 109            ----      Mean_T_V
# 110            ----      ArmMean_T_V
# 111            ----      RMS_T_V
# 112            ----      Variance_T_V
# 113            ----      STD_T_V
# 114            ----      Kurtosis_T_V
# 115            ----      Skewness_T_V
# 116            ----      TrimMean_T_V
# 117            ----      AsymmetryCoefficient_T_V
# 118            ----      ZCR_T_V
# 119            ----      MCR_T_V
# 120            ----      Range_T_V
#
# 121            ----      Minimum_A_F
# 122            ----      Maximum_A_F
# 123            ----      Median_A_F
# 124            ----      Mean_A_F
# 125            ----      ArmMean_A_F
# 126            ----      RMS_A_F
# 127            ----      Variance_A_F
# 128            ----      STD_A_F
# 129            ----      Kurtosis_A_F
# 130            ----      Skewness_A_F
# 131            ----      TrimMean_A_F
# 132            ----      AsymmetryCoefficient_A_F
# 133            ----      ZCR_A_F
# 134            ----      MCR_A_F
# 135            ----      Range_A_F

# %% [raw]
# freq_1.csv
#
# 136 +
#
# 0            ----        FreezingIndex_A_F
# 1            ----        FreezingIndex_A_V
# 2            ----        FreezingIndex_A_L
# 3            ----        FreezingIndex_L_F
# 4            ----        FreezingIndex_L_V
# 5            ----        FreezingIndex_L_L
# 6            ----        FreezingIndex_T_F
# 7            ----        FreezingIndex_T_V
# 8            ----        FreezingIndex_T_L
#
# 9            ----         Power_A_F
# 10            ----        Power_A_V
# 11            ----        Power_A_L
# 12            ----        Power_L_F
# 13            ----        Power_L_V
# 14            ----        Power_L_L
# 15            ----        Power_T_F
# 16            ----        Power_T_V
# 17            ----        Power_T_L
#
# 18            ----        Energy_A_F
# 19            ----        Energy_A_V
# 20            ----        Energy_A_L
# 21            ----        Energy_L_F
# 22            ----        Energy_L_V
# 23            ----        Energy_L_L
# 24            ----        Energy_T_F
# 25            ----        Energy_T_V
# 26            ----        Energy_T_L
#
# 27            ----        PeakFrequency_A_F
# 28            ----        PeakFrequency_A_V
# 29            ----        PeakFrequency_A_L
# 30            ----        PeakFrequency_L_F
# 31            ----        PeakFrequency_L_V
# 32            ----        PeakFrequency_L_L
# 33            ----        PeakFrequency_T_F
# 34            ----        PeakFrequency_T_V
# 35            ----        PeakFrequency_T_L
#
# 36            ----        Entropy_A_F
# 37            ----        Entropy_A_V
# 38            ----        Entropy_A_L
# 39            ----        Entropy_L_F
# 40            ----        Entropy_L_V
# 41            ----        Entropy_L_L
# 42            ----        Entropy_T_F
# 43            ----        Entropy_T_V
# 44            ----        Entropy_T_L

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.utils import shuffle

os.getcwd()
# Out:
# 'F:\\KARTIK\\2021\\Freezing of Gait'

# %%
data_path_1 = os.path.join(os.getcwd(), 'dataset_fog_release', 'dataset', 'features', 'freq_1.csv')
if os.path.exists(data_path_1):
    print(True)
    
data_path_2 = os.path.join(os.getcwd(), 'dataset_fog_release', 'dataset', 'features', 'time_1.csv')
if os.path.exists(data_path_2):
    print(True)

#Load the time features
time_features = pd.read_csv(data_path_2)

#Load the frequency features
freq_features = pd.read_csv(data_path_1)
# Out:
# True
# True

# %%
final_features = pd.concat([time_features, freq_features], axis = 1)
final_features.head()
final_features.to_csv("final_features.csv")

# %%
data_path = os.path.join(os.getcwd(), 'dataset_fog_release', 'dataset', 'features', 'final_features.csv')
final_features = pd.read_csv(data_path)
print(final_features.shape)
print(final_features.head())
# Out:
# (12658, 181)
#    0  Minimum_A_F  Maximum_A_F  Median_A_F   Mean_A_F  ArmMean_A_F    RMS_A_F  \
# 0  0         -121           90       -50.0 -50.875000     0.000000  64.817773
# 1  0         -121           40       -50.0 -49.000000     0.000000  60.410833
# 2  0          -90           50       -50.0 -48.437500     0.000000  55.761770
# 3  0         -161           40       -50.0 -52.390625    34.896197  63.512179
# 4  0         -141           20       -60.0 -58.656250    48.458215  64.156060
#
#    Variance_A_F    STD_A_F  Kurtosis_A_F  ...    peak_T_L   ENt_A_F   ENt_A_V  \
# 0   1613.078125  40.163144      2.808410  ...   50.242196  2.848596  2.773791
# 1   1248.468750  35.333677     -0.615322  ...   45.497903  2.367487  3.110655
# 2    763.183594  27.625778      3.044294  ...  126.459278  2.113819  3.063275
# 3   1289.019287  35.902915      1.414610  ...  202.260174  2.267055  2.900160
# 4    675.444336  25.989312      1.215502  ...  120.858665  3.036838  2.981486
#
# ...

# %%
def select_columns(feature_cols, final_features):
    features = [final_features.iloc[:,feature_cols]]
    final_features = pd.concat(features, axis = 1)

    #Get the shape of the dataframe
    final_features.shape
    return final_features

# %%
# size of walk is 1.5 times the size of prefog

# %%
def select_rows(dataset, size_of_walk = 1.5):
    size_of_walk = 1.5
    fraction = int(237 * size_of_walk)
    print(fraction)
    y_1 = dataset[dataset['0'] == 1]
    y_2 = dataset[dataset['0'] == 2]
    y_0 = dataset[dataset['0'] == 0].sample( n = fraction)
    
    y = pd.concat([y_0, y_1, y_2], axis = 0)
    
    #y.to_csv("F_ftrs_rows_" + size_of_walk + "_.csv")
    
    #y_00 = time_features[time_features['0'] == 0]
    os.chdir(r"F:\KARTIK\2021\Freezing of Gait\dataset_fog_release\dataset\FINAL FEATURES")
    y.to_csv("final_ftrs_size_" + str(size_of_walk) + "_6.csv")
    return y

# %%
cols = select_columns([0,1,2,6,7,8,9,10,15,16,17,21,22,23,24,25,30,31,32,36,37,38,39,45,145,146,147,154,155,156,172,173,174], final_features)
df = select_rows(cols)
# Out:
# 355
